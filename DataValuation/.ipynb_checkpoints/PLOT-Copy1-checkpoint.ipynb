# %%
# %history -f PLOT3.ipynb

# %%
# from low w high
x_h = np.array([0.6, 0.7, 0.8, 0.9, 1.0])

y_mnist_l2h = np.array([0.005296296,0.004277778,0.003833333, 0.003277778,0.003148148])
y_mnist_l2h_ = y_mnist_l2h[::-1]
y_mnist_h2l = np.array([0.025648148, 0.018888889, 0.018833333, 0.008833333, 0.008685185])
y_mnist_h2l_ = y_mnist_h2l[::-1]
# y_cifar10 = [0.020033333,0.0239,0.0255,0.026277778,0.06431146]
# y_usps = [0.053348169,0.112205334,0.145173959,0.243849553,0.316322416]

plt.plot(x_h, y_mnist_l2h_,'x-', label='Removing low value data', markersize=12, linewidth=3)
plt.plot(x_h, y_mnist_h2l_,'x-', label='Removing high value data', markersize=12, linewidth=3)
# plt.plot(x_h, y_usps,'x-', label='USPS', markersize=12,linewidth=3)
# plt.plot(x_h, y_cifar10,'x-', label='CIFAR-10', markersize=12,linewidth=3)
# plt.bar(x_h-width, y_mnist, label='100 samples', width=width)
# plt.bar(x_h, y_mnist, label='100 samples', width=width)

plt.xlabel('Proportion of mislabeled data (%)', font1)
_ = plt.ylabel('Effectiveness score', font2)
plt.legend(loc=[0.25, 0.72], prop=font)
plt.tick_params(labelsize=16)
plt.show()
